# %% [markdown]
# # Aufgabe 3 - Tiefe Einblicke ins Institut: Reloaded

# %% [markdown]
# Den Code immer nachvollziehbar kommentieren! Bitte beachtet, dass das Notebook von Anfang bis Ende ohne Fehler durchlaufen muss und dass die requirements.txt Datei aktualisiert wird.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
import torch.optim as optim
from torchvision.io import read_image
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

import numpy as np
import matplotlib.pyplot as plt

EARLY_STOP = False

# %% [markdown]
# ## Teilaufgabe a): Trainings-, Test-und Validierungsdatenset

# %%
import os
import random
import math
import re

random.seed(322)

training_path_list = []  # Gleiche Liste aus Aufgabe 2
test_path_list = []  # Gleiche Liste aus Aufgabe 2
validation_path_list = []  # ["./pfad/zu/bildZ.png","./pfad/zu/bildY.png",...]

RE_FILE = re.compile(r"[a-zA-Z]+\d+\.jpg")


def create_data_split(folder, label: int, train_percent, test_percent, val_percent, base_only=True):
    """
    :param base_only: Only include base files, no augmented ones
    """

    assert train_percent + test_percent == 1, "train and test percentages dont add up to 1.0"
    assert 0 < val_percent <= 1, "validation percent must be within [0..1]"
    files = os.listdir(folder)
    if base_only:
        files = [f for f in files if RE_FILE.match(f)]
    random.shuffle(files)

    train_cnt = math.ceil(len(files) * train_percent)
    val_cnt = math.ceil(train_cnt * val_percent)
    train_files = [f'{folder}/{f}' for f in files[:train_cnt]]
    test_files = [f'{folder}/{f}' for f in files[train_cnt:]]
    valid_files = train_files[:val_cnt]

    random.shuffle(train_files)
    random.shuffle(test_files)
    random.shuffle(valid_files)

    return list(zip(train_files, [label] * len(train_files))), \
        list(zip(test_files, [label] * len(test_files))), \
        list(zip(valid_files, [label] * len(valid_files)))


def create_full_data_split(base_only=True):
    train_percent = 0.7
    test_percent = 0.3
    val_percent = 0.3

    flur_train, flur_test, flur_val = create_data_split('Bilder/Flur', 0, train_percent, test_percent, val_percent,
                                                        base_only)
    labo_train, labo_test, labo_val = create_data_split('Bilder/Labor', 1, train_percent, test_percent, val_percent,
                                                        base_only)
    prof_train, prof_test, prof_val = create_data_split('Bilder/Professorenbuero', 2, train_percent, test_percent,
                                                        val_percent, base_only)
    teek_train, teek_test, teek_val = create_data_split('Bilder/Teekueche', 3, train_percent, test_percent, val_percent,
                                                        base_only)

    train_files = flur_train + labo_train + prof_train + teek_train
    test_files = flur_test + labo_test + prof_test + teek_test
    val_files = flur_val + labo_val + prof_val + teek_val

    random.shuffle(train_files)
    random.shuffle(test_files)
    random.shuffle(val_files)

    train_batch_len = (len(train_files) // 16) * 16
    test_batch_len = (len(test_files) // 16) * 16
    val_batch_len = (len(val_files) // 16) * 16

    return (
        [f[0] for f in train_files][:train_batch_len],
        [f[1] for f in train_files][:train_batch_len],
        [f[0] for f in test_files][:test_batch_len],
        [f[1] for f in test_files][:test_batch_len],
        [f[0] for f in val_files][:val_batch_len],
        [f[1] for f in val_files][:val_batch_len],
    )


# Labels are: Flur=0, Labor=1, Professorenbuero=2, Teekueche=3
training_path_list, y_train, test_path_list, y_test, validation_path_list, y_val = create_full_data_split()

# %% [markdown]
# ## Teilaufgabe b): CNN definieren und implementieren

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 53 * 53, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 4)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)  # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x  #%% md

# Aufgabe 3 - Tiefe Einblicke ins Institut: Reloaded

# %% [markdown]
# Datenset-Klasse um mit Pytorch Bilder zu laden.
#
# Input sind:
# - Liste mit Pfaden zu Bildern
# - Liste mit dazugehörigen Labels (numerisch darstellen!)
# - Transformation der Bilder

# %%
class ROBDataset(Dataset):
    def __init__(self, img_path_list, img_labels, transform=None):
        # Pfade zu den Bildern als list
        self.img_path_list = img_path_list

        # Dazugehörige Labels zu den Bildern als list
        self.img_labels = img_labels

        # Transformations der Bilder
        self.transform = transform

    def __len__(self):
        return len(self.img_path_list)

    def __getitem__(self, idx):
        # Bild laden
        img_path = self.img_path_list[idx]
        image = read_image(img_path)

        # Label laden
        label = self.img_labels[idx]

        # Transformieren
        if self.transform:
            image = self.transform(image)

        return image.float(), int(label)

# %% [markdown]
# Trainingsiteration über alle Bilder.
#
# Inputs sind:
# - Pytorch dataloader Object über das iteriert wird
# - bool do_backprob Parameter um Backpropagation durchzuführen oder nicht

# %%
from torchmetrics import Accuracy
def accuracy_score(output, labels):
    output = torch.from_numpy(output)
    labels = torch.from_numpy(labels)
    acc = Accuracy(task="multiclass", num_classes=4)
    r = acc(output, labels)
    return r

# Iterating over the entire data set once
def run_iteration(dataloader, do_backprob=True):
    global net, optimizer, criterion
    loss_iter = []
    acc_iter = []
    for batch_x, batch_y in dataloader:
        # To device
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        y_predict = net(batch_x)
        loss = criterion(y_predict, batch_y)
        if do_backprob:
            loss.backward()
            optimizer.step()

        # statistics
        loss_iter.append(loss.detach().cpu().numpy())

        _, predicted = torch.max(torch.softmax(y_predict, dim=1),1)

        acc_iter.append(accuracy_score(batch_y.detach().cpu().numpy(),
                                       predicted.detach().cpu().numpy()))

    return np.mean(loss_iter), np.mean(acc_iter)

# %% [markdown]
# Komplette Durchführung eines Trainings
# Die Variablen y_train, y_val und y_test müssen noch gesetzt werden. Diese Listen beinhalten die entsprechenden Labels als numerische Darstellung.

# %%
# Get the device. This adds support for DirectML as I have an AMD GPU, which is a giant pain for machine learning (*cries over awful ROCm installation instructions*)
try:
    import torch_directml
    device = torch_directml.device()
    print('Found DirectML')
except ModuleNotFoundError:
    print('No DirectML found. Using CUDA / CPU instead')
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Found DirectML

# %%
# Training settings - bei Bedarf anpassbar
max_epoch = 100
batch_size = 16
lr = 0.001
early_stop_cnt = 0
early_stop_min_delta = 0.000001
early_stop_tolerance = 5

# Transformations for dataloader
t_train = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_val = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_test = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])

# Where to do calculations
print("Running on ", device)
print(f'Train / test images: {len(training_path_list)}/{len(test_path_list)}')

# Training Data, NOTE: y_train labels need to be set
dataset_train = ROBDataset(training_path_list, y_train, transform=t_train)
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# Validation Data, NOTE: y_val labels need to be set
dataset_val = ROBDataset(validation_path_list, y_val, transform=t_train)
dataloader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# Test Data, NOTE: y_test labels need. to be set
dataset_test = ROBDataset(test_path_list, y_test,transform=t_test)
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

# Network, optimizer and loss initialisation
net = Net()
net.to(device)
optimizer = optim.Adam(net.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# Los geht's mit Training
print("\nStarted Training")
# Training loss and accuracy per epoch
train_loss_epoch = []
train_acc_epoch = []
# Validation loss and accuracy per epoch
val_loss_epoch = []
val_acc_epoch = []

for epoch in range(0,max_epoch):  # loop over the dataset multiple times
    print(f"Epoch {epoch+1} from {max_epoch}")

    ### TRAINING ###
    net.train()
    train_loss_iter, train_acc_iter = run_iteration(dataloader_train)

    # Logging loss and accuarcy of training iteration
    train_loss_epoch.append(train_loss_iter)
    train_acc_epoch.append(train_acc_iter)
    print("\tTrain Loss\t",train_loss_iter)
    print("\tTrain Acc.\t",train_acc_iter)

    ### VALIDATION ###
    with torch.no_grad():  # No gradient calculation
        net.eval()
        val_loss_iter, val_acc_iter = run_iteration(dataloader_val,do_backprob=False)

        # Logging loss and accuarcy of validation iteration
        val_loss_epoch.append(val_loss_iter)
        val_acc_epoch.append(val_acc_iter)
        print("\tVal Loss\t",val_loss_iter)
        print("\tVal Acc.\t",val_acc_iter)

    if EARLY_STOP:
        loss_diff = abs(val_loss_iter - train_loss_iter)
        print(f'\tDiff\t\t {loss_diff}')
        if loss_diff < early_stop_min_delta:
            early_stop_cnt += 1
            if early_stop_cnt >= early_stop_tolerance:
                print(f"[EARLY STOP] Reached early stop at epoch {epoch}.")
                break

# Plotting results
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(10,3))
ax[0].plot(train_loss_epoch,label="Train")
ax[0].plot(val_loss_epoch,label="Val",linestyle="-.")
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epochs')
ax[0].legend()

ax[1].plot(train_acc_epoch,label="Train")
ax[1].plot(val_acc_epoch,label="Val",linestyle="-.")
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].legend()
plt.savefig("loss_augmentation.png",format="png",bbox_inches="tight")
plt.show()
# Out:
# Running on  privateuseone:0
# Train / test images: 64/16
#
# Started Training
# Epoch 1 from 100
# 	Train Loss	 1.542486
# 	Train Acc.	 0.234375
# 	Val Loss	 1.3598464
# 	Val Acc.	 0.3125
# Epoch 2 from 100
# 	Train Loss	 1.35546
# 	Train Acc.	 0.265625
# 	Val Loss	 1.3030596
# 	Val Acc.	 0.8125
# Epoch 3 from 100
# 	Train Loss	 1.2515694
# 	Train Acc.	 0.765625
# 	Val Loss	 1.1403148
# 	Val Acc.	 0.6875
# Epoch 4 from 100
# 	Train Loss	 1.0101111
# 	Train Acc.	 0.859375
# 	Val Loss	 0.8161583
# 	Val Acc.	 0.875
# Epoch 5 from 100
# 	Train Loss	 0.664229
# 	Train Acc.	 0.828125
# 	Val Loss	 0.5298657
# 	Val Acc.	 0.75
# Epoch 6 from 100
# 	Train Loss	 0.36977348
# 	Train Acc.	 0.953125
# 	Val Loss	 0.27944916
# 	Val Acc.	 0.9375
# Epoch 7 from 100
# 	Train Loss	 0.2274705
# 	Train Acc.	 0.984375
# 	Val Loss	 0.2050311
# 	Val Acc.	 0.9375
# Epoch 8 from 100
# 	Train Loss	 0.108191386
# 	Train Acc.	 0.96875
# 	Val Loss	 0.42315876
# 	Val Acc.	 0.9375
# Epoch 9 from 100
# 	Train Loss	 0.043116402
# 	Train Acc.	 1.0
# 	Val Loss	 0.2060475
# 	Val Acc.	 0.9375
# Epoch 10 from 100
# 	Train Loss	 0.015566729
# 	Train Acc.	 1.0
# 	Val Loss	 0.11828782
# 	Val Acc.	 0.9375
# Epoch 11 from 100
# 	Train Loss	 0.0077681467
# 	Train Acc.	 1.0
# 	Val Loss	 0.22826983
# 	Val Acc.	 0.9375
# Epoch 12 from 100
# 	Train Loss	 0.0022569126
# 	Train Acc.	 1.0
# 	Val Loss	 0.36643225
# 	Val Acc.	 0.9375
# Epoch 13 from 100
# 	Train Loss	 0.001985129
# 	Train Acc.	 1.0
# 	Val Loss	 0.44374985
# 	Val Acc.	 0.9375
# Epoch 14 from 100
# 	Train Loss	 0.0018723605
# 	Train Acc.	 1.0
# 	Val Loss	 0.45860103
# 	Val Acc.	 0.9375
# Epoch 15 from 100
# 	Train Loss	 0.0010689922
# 	Train Acc.	 1.0
# 	Val Loss	 0.4370004
# 	Val Acc.	 0.9375
# Epoch 16 from 100
# 	Train Loss	 0.00063487433
# 	Train Acc.	 1.0
# 	Val Loss	 0.405103
# 	Val Acc.	 0.9375
# Epoch 17 from 100
# 	Train Loss	 0.0004587466
# 	Train Acc.	 1.0
# 	Val Loss	 0.37719607
# 	Val Acc.	 0.9375
# Epoch 18 from 100
# 	Train Loss	 0.0003744826
# 	Train Acc.	 1.0
# 	Val Loss	 0.35787094
# 	Val Acc.	 0.9375
# Epoch 19 from 100
# 	Train Loss	 0.00032748893
# 	Train Acc.	 1.0
# 	Val Loss	 0.33930823
# 	Val Acc.	 0.9375
# Epoch 20 from 100
# 	Train Loss	 0.0002946854
# 	Train Acc.	 1.0
# 	Val Loss	 0.31879973
# 	Val Acc.	 0.9375
# Epoch 21 from 100
# 	Train Loss	 0.00026036514
# 	Train Acc.	 1.0
# 	Val Loss	 0.3389037
# 	Val Acc.	 0.9375
# Epoch 22 from 100
# 	Train Loss	 0.0002337918
# 	Train Acc.	 1.0
# 	Val Loss	 0.3455994
# 	Val Acc.	 0.9375
# Epoch 23 from 100
# 	Train Loss	 0.00021275487
# 	Train Acc.	 1.0
# 	Val Loss	 0.35163635
# 	Val Acc.	 0.9375
# Epoch 24 from 100
# 	Train Loss	 0.00019506206
# 	Train Acc.	 1.0
# 	Val Loss	 0.35851476
# 	Val Acc.	 0.9375
# Epoch 25 from 100
# 	Train Loss	 0.00017710867
# 	Train Acc.	 1.0
# 	Val Loss	 0.36517793
# 	Val Acc.	 0.9375
# Epoch 26 from 100
# 	Train Loss	 0.00016053689
# 	Train Acc.	 1.0
# 	Val Loss	 0.37166604
# 	Val Acc.	 0.9375
# Epoch 27 from 100
# 	Train Loss	 0.00014705965
# 	Train Acc.	 1.0
# 	Val Loss	 0.37753758
# 	Val Acc.	 0.9375
# Epoch 28 from 100
# 	Train Loss	 0.00013666708
# 	Train Acc.	 1.0
# 	Val Loss	 0.3825205
# 	Val Acc.	 0.9375
# Epoch 29 from 100
# 	Train Loss	 0.00012516856
# 	Train Acc.	 1.0
# 	Val Loss	 0.3819131
# 	Val Acc.	 0.9375
# Epoch 30 from 100
# 	Train Loss	 0.0001183368
# 	Train Acc.	 1.0
# 	Val Loss	 0.38437176
# 	Val Acc.	 0.9375
# Epoch 31 from 100
# 	Train Loss	 0.00011163173
# 	Train Acc.	 1.0
# 	Val Loss	 0.3890981
# 	Val Acc.	 0.9375
# Epoch 32 from 100
# 	Train Loss	 0.00010584259
# 	Train Acc.	 1.0
# 	Val Loss	 0.39598763
# 	Val Acc.	 0.9375
# Epoch 33 from 100
# 	Train Loss	 9.978545e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.40031862
# 	Val Acc.	 0.9375
# Epoch 34 from 100
# 	Train Loss	 9.516381e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.40523914
# 	Val Acc.	 0.9375
# Epoch 35 from 100
# 	Train Loss	 9.033557e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.40860283
# 	Val Acc.	 0.9375
# Epoch 36 from 100
# 	Train Loss	 8.587768e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.41208404
# 	Val Acc.	 0.9375
# Epoch 37 from 100
# 	Train Loss	 8.2317136e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4148994
# 	Val Acc.	 0.9375
# Epoch 38 from 100
# 	Train Loss	 7.8427074e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.41883004
# 	Val Acc.	 0.9375
# Epoch 39 from 100
# 	Train Loss	 7.445318e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.42239773
# 	Val Acc.	 0.9375
# Epoch 40 from 100
# 	Train Loss	 7.0924245e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.42419758
# 	Val Acc.	 0.9375
# Epoch 41 from 100
# 	Train Loss	 6.7985486e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.42739952
# 	Val Acc.	 0.9375
# Epoch 42 from 100
# 	Train Loss	 6.51306e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.43151715
# 	Val Acc.	 0.9375
# Epoch 43 from 100
# 	Train Loss	 6.240416e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.43374994
# 	Val Acc.	 0.9375
# Epoch 44 from 100
# 	Train Loss	 5.9653503e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.43695292
# 	Val Acc.	 0.9375
# Epoch 45 from 100
# 	Train Loss	 5.708161e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.43848976
# 	Val Acc.	 0.9375
# Epoch 46 from 100
# 	Train Loss	 5.5006974e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.43876037
# 	Val Acc.	 0.9375
# Epoch 47 from 100
# 	Train Loss	 5.2775886e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.44082576
# 	Val Acc.	 0.9375
# Epoch 48 from 100
# 	Train Loss	 5.070676e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4449813
# 	Val Acc.	 0.9375
# Epoch 49 from 100
# 	Train Loss	 4.872148e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.44797122
# 	Val Acc.	 0.9375
# Epoch 50 from 100
# 	Train Loss	 4.6672856e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.44864988
# 	Val Acc.	 0.9375
# Epoch 51 from 100
# 	Train Loss	 4.507678e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.45167208
# 	Val Acc.	 0.9375
# Epoch 52 from 100
# 	Train Loss	 4.3527256e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4529327
# 	Val Acc.	 0.9375
# Epoch 53 from 100
# 	Train Loss	 4.18567e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.453458
# 	Val Acc.	 0.9375
# Epoch 54 from 100
# 	Train Loss	 4.0258732e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4532813
# 	Val Acc.	 0.9375
# Epoch 55 from 100
# 	Train Loss	 3.9117054e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.45478392
# 	Val Acc.	 0.9375
# Epoch 56 from 100
# 	Train Loss	 3.765132e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.45698786
# 	Val Acc.	 0.9375
# Epoch 57 from 100
# 	Train Loss	 3.6515226e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.45783067
# 	Val Acc.	 0.9375
# Epoch 58 from 100
# 	Train Loss	 3.521709e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4608715
# 	Val Acc.	 0.9375
# Epoch 59 from 100
# 	Train Loss	 3.4045617e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.46352533
# 	Val Acc.	 0.9375
# Epoch 60 from 100
# 	Train Loss	 3.3082717e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.46548438
# 	Val Acc.	 0.9375
# Epoch 61 from 100
# 	Train Loss	 3.201553e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.46498552
# 	Val Acc.	 0.9375
# Epoch 62 from 100
# 	Train Loss	 3.097068e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.46703377
# 	Val Acc.	 0.9375
# Epoch 63 from 100
# 	Train Loss	 3.0059928e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4681605
# 	Val Acc.	 0.9375
# Epoch 64 from 100
# 	Train Loss	 2.91529e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.46926832
# 	Val Acc.	 0.9375
# Epoch 65 from 100
# 	Train Loss	 2.8301742e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.470889
# 	Val Acc.	 0.9375
# Epoch 66 from 100
# 	Train Loss	 2.7499e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4724917
# 	Val Acc.	 0.9375
# Epoch 67 from 100
# 	Train Loss	 2.6698122e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.47424674
# 	Val Acc.	 0.9375
# Epoch 68 from 100
# 	Train Loss	 2.5921458e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.47587064
# 	Val Acc.	 0.9375
# Epoch 69 from 100
# 	Train Loss	 2.529379e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.478317
# 	Val Acc.	 0.9375
# Epoch 70 from 100
# 	Train Loss	 2.4602796e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4796789
# 	Val Acc.	 0.9375
# Epoch 71 from 100
# 	Train Loss	 2.391553e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.48066103
# 	Val Acc.	 0.9375
# Epoch 72 from 100
# 	Train Loss	 2.330463e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.48167956
# 	Val Acc.	 0.9375
# Epoch 73 from 100
# 	Train Loss	 2.2691856e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.48341498
# 	Val Acc.	 0.9375
# Epoch 74 from 100
# 	Train Loss	 2.2127511e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4845015
# 	Val Acc.	 0.9375
# Epoch 75 from 100
# 	Train Loss	 2.1555716e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.48417163
# 	Val Acc.	 0.9375
# Epoch 76 from 100
# 	Train Loss	 2.1071452e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4853123
# 	Val Acc.	 0.9375
# Epoch 77 from 100
# 	Train Loss	 2.0512694e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4871923
# 	Val Acc.	 0.9375
# Epoch 78 from 100
# 	Train Loss	 2.0075002e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.48851305
# 	Val Acc.	 0.9375
# Epoch 79 from 100
# 	Train Loss	 1.9585155e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.49016574
# 	Val Acc.	 0.9375
# Epoch 80 from 100
# 	Train Loss	 1.9089723e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4915924
# 	Val Acc.	 0.9375
# Epoch 81 from 100
# 	Train Loss	 1.8666922e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.49331838
# 	Val Acc.	 0.9375
# Epoch 82 from 100
# 	Train Loss	 1.824971e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.49470052
# 	Val Acc.	 0.9375
# Epoch 83 from 100
# 	Train Loss	 1.786416e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4948797
# 	Val Acc.	 0.9375
# Epoch 84 from 100
# 	Train Loss	 1.7419012e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.4960596
# 	Val Acc.	 0.9375
# Epoch 85 from 100
# 	Train Loss	 1.7026012e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.49722862
# 	Val Acc.	 0.9375
# Epoch 86 from 100
# 	Train Loss	 1.6683302e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.49945396
# 	Val Acc.	 0.9375
# Epoch 87 from 100
# 	Train Loss	 1.6323831e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.50063455
# 	Val Acc.	 0.9375
# Epoch 88 from 100
# 	Train Loss	 1.6005333e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.50172883
# 	Val Acc.	 0.9375
# Epoch 89 from 100
# 	Train Loss	 1.5642132e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.50246
# 	Val Acc.	 0.9375
# Epoch 90 from 100
# 	Train Loss	 1.5355296e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.5032324
# 	Val Acc.	 0.9375
# Epoch 91 from 100
# 	Train Loss	 1.5064736e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.5042889
# 	Val Acc.	 0.9375
# Epoch 92 from 100
# 	Train Loss	 1.47313385e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.50569636
# 	Val Acc.	 0.9375
# Epoch 93 from 100
# 	Train Loss	 1.445754e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.5064117
# 	Val Acc.	 0.9375
# Epoch 94 from 100
# 	Train Loss	 1.4166982e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.5075435
# 	Val Acc.	 0.9375
# Epoch 95 from 100
# 	Train Loss	 1.3924847e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.50928104
# 	Val Acc.	 0.9375
# Epoch 96 from 100
# 	Train Loss	 1.3606346e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.50957346
# 	Val Acc.	 0.9375
# Epoch 97 from 100
# 	Train Loss	 1.3394012e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.51146066
# 	Val Acc.	 0.9375
# Epoch 98 from 100
# 	Train Loss	 1.3140703e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.5125287
# 	Val Acc.	 0.9375
# Epoch 99 from 100
# 	Train Loss	 1.288553e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.51399004
# 	Val Acc.	 0.9375
# Epoch 100 from 100
# 	Train Loss	 1.26471205e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.51368165
# 	Val Acc.	 0.9375

# %% [markdown]
# ## Teilaufgabe d): Augmentierung

# %%
"""
Possible ways to augment the data would be to flip and rotate the images as well as add color filters like grayscale. Other possible techniques could be kernel filters (to change sharpness) or cropping the image
"""
from natsort import natsorted

def make_grayscale(input_file: str, output_file: str):
    image = Image.open(input_file)
    grayscale_image = image.convert('L')
    grayscale_image_3_chn = grayscale_image.convert('RGB')  # Must keep 3 channels
    grayscale_image_3_chn.save(output_file)

def flip_image(input_file: str, output_file: str):
    image = Image.open(input_file)
    flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
    flipped_image.save(output_file)


# Create new images
for folder in ('Flur', 'Labor', 'Professorenbuero', 'Teekueche'):
    # Delete existing images
    folder_path = f'Bilder/{folder}'
    files = natsorted([f for f in os.listdir(folder_path) if RE_FILE.match(f)])
    for i, file in enumerate(files):
        make_grayscale(f'{folder_path}/{file}', f'{folder_path}/{folder}_gray_{i + 1}.jpg')
        flip_image(f'{folder_path}/{file}', f'{folder_path}/{folder}_flipped_{i + 1}.jpg')

# %%
# Modify training / test / validation data
training_path_list, y_train, test_path_list, y_test, validation_path_list, y_val = create_full_data_split(base_only=False)

"""
Da die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.
Es scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint
"""
# Out:
# '\nDa die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.\nEs scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint\n'

# %% [markdown]
# ## Teilaufgabe e): Early Stopping

# %%
EARLY_STOP = True
"""
The overfitting stops and the training is faster
"""
# Out:
# '\nThe overfitting stops and the training is faster\n'

# %% [markdown]
# ## Teilaufgabe c): Training und Test mit CNN

# %% [markdown]
# Datenset-Klasse um mit Pytorch Bilder zu laden.
#
# Input sind:
# - Liste mit Pfaden zu Bildern
# - Liste mit dazugehörigen Labels (numerisch darstellen!)
# - Transformation der Bilder

# %%
class ROBDataset(Dataset):
    def __init__(self, img_path_list, img_labels, transform=None):
        # Pfade zu den Bildern als list
        self.img_path_list = img_path_list

        # Dazugehörige Labels zu den Bildern als list
        self.img_labels = img_labels

        # Transformations der Bilder
        self.transform = transform

    def __len__(self):
        return len(self.img_path_list)

    def __getitem__(self, idx):
        # Bild laden
        img_path = self.img_path_list[idx]
        image = read_image(img_path)

        # Label laden
        label = self.img_labels[idx]

        # Transformieren
        if self.transform:
            image = self.transform(image)

        return image.float(), int(label)

# %% [markdown]
# Trainingsiteration über alle Bilder.
#
# Inputs sind:
# - Pytorch dataloader Object über das iteriert wird
# - bool do_backprob Parameter um Backpropagation durchzuführen oder nicht

# %%
from torchmetrics import Accuracy
def accuracy_score(output, labels):
    output = torch.from_numpy(output)
    labels = torch.from_numpy(labels)
    acc = Accuracy(task="multiclass", num_classes=4)
    r = acc(output, labels)
    return r

# Iterating over the entire data set once
def run_iteration(dataloader, do_backprob=True):
    global net, optimizer, criterion
    loss_iter = []
    acc_iter = []
    for batch_x, batch_y in dataloader:
        # To device
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        y_predict = net(batch_x)
        loss = criterion(y_predict, batch_y)
        if do_backprob:
            loss.backward()
            optimizer.step()

        # statistics
        loss_iter.append(loss.detach().cpu().numpy())

        _, predicted = torch.max(torch.softmax(y_predict, dim=1),1)

        acc_iter.append(accuracy_score(batch_y.detach().cpu().numpy(),
                                       predicted.detach().cpu().numpy()))

    return np.mean(loss_iter), np.mean(acc_iter)

# %% [markdown]
# Komplette Durchführung eines Trainings
# Die Variablen y_train, y_val und y_test müssen noch gesetzt werden. Diese Listen beinhalten die entsprechenden Labels als numerische Darstellung.

# %%
# Get the device. This adds support for DirectML as I have an AMD GPU, which is a giant pain for machine learning (*cries over awful ROCm installation instructions*)
try:
    import torch_directml
    device = torch_directml.device()
    print('Found DirectML')
except ModuleNotFoundError:
    print('No DirectML found. Using CUDA / CPU instead')
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Found DirectML

# %%
# Training settings - bei Bedarf anpassbar
max_epoch = 100
batch_size = 16
lr = 0.001
early_stop_cnt = 0
early_stop_min_delta = 0.000001
early_stop_tolerance = 5

# Transformations for dataloader
t_train = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_val = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_test = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])

# Where to do calculations
print("Running on ", device)
print(f'Train / test images: {len(training_path_list)}/{len(test_path_list)}')

# Training Data, NOTE: y_train labels need to be set
dataset_train = ROBDataset(training_path_list, y_train, transform=t_train)
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# Validation Data, NOTE: y_val labels need to be set
dataset_val = ROBDataset(validation_path_list, y_val, transform=t_train)
dataloader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# Test Data, NOTE: y_test labels need. to be set
dataset_test = ROBDataset(test_path_list, y_test,transform=t_test)
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

# Network, optimizer and loss initialisation
net = Net()
net.to(device)
optimizer = optim.Adam(net.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# Los geht's mit Training
print("\nStarted Training")
# Training loss and accuracy per epoch
train_loss_epoch = []
train_acc_epoch = []
# Validation loss and accuracy per epoch
val_loss_epoch = []
val_acc_epoch = []

for epoch in range(0,max_epoch):  # loop over the dataset multiple times
    print(f"Epoch {epoch+1} from {max_epoch}")

    ### TRAINING ###
    net.train()
    train_loss_iter, train_acc_iter = run_iteration(dataloader_train)

    # Logging loss and accuarcy of training iteration
    train_loss_epoch.append(train_loss_iter)
    train_acc_epoch.append(train_acc_iter)
    print("\tTrain Loss\t",train_loss_iter)
    print("\tTrain Acc.\t",train_acc_iter)

    ### VALIDATION ###
    with torch.no_grad():  # No gradient calculation
        net.eval()
        val_loss_iter, val_acc_iter = run_iteration(dataloader_val,do_backprob=False)

        # Logging loss and accuarcy of validation iteration
        val_loss_epoch.append(val_loss_iter)
        val_acc_epoch.append(val_acc_iter)
        print("\tVal Loss\t",val_loss_iter)
        print("\tVal Acc.\t",val_acc_iter)

    if EARLY_STOP:
        loss_diff = abs(val_loss_iter - train_loss_iter)
        print(f'\tDiff\t\t {loss_diff}')
        if loss_diff < early_stop_min_delta:
            early_stop_cnt += 1
            if early_stop_cnt >= early_stop_tolerance:
                print(f"[EARLY STOP] Reached early stop at epoch {epoch}.")
                break

# Plotting results
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(10,3))
ax[0].plot(train_loss_epoch,label="Train")
ax[0].plot(val_loss_epoch,label="Val",linestyle="-.")
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epochs')
ax[0].legend()

ax[1].plot(train_acc_epoch,label="Train")
ax[1].plot(val_acc_epoch,label="Val",linestyle="-.")
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].legend()
plt.savefig("loss_augmentation.png",format="png",bbox_inches="tight")
plt.show()
# Out:
# Running on  privateuseone:0
# Train / test images: 208/80
#
# Started Training
# Epoch 1 from 100
# 	Train Loss	 1.4531757
# 	Train Acc.	 0.29326922
# 	Val Loss	 1.1386275
# 	Val Acc.	 0.59375
# 	Diff		 0.314548134803772
# Epoch 2 from 100
# 	Train Loss	 0.8563411
# 	Train Acc.	 0.7019231
# 	Val Loss	 0.7674304
# 	Val Acc.	 0.625
# 	Diff		 0.08891069889068604
# Epoch 3 from 100
# 	Train Loss	 0.45618168
# 	Train Acc.	 0.8269231
# 	Val Loss	 0.44625166
# 	Val Acc.	 0.8125
# 	Diff		 0.009930014610290527
# Epoch 4 from 100
# 	Train Loss	 0.22797045
# 	Train Acc.	 0.9326923
# 	Val Loss	 0.07465342
# 	Val Acc.	 0.984375
# 	Diff		 0.15331703424453735
# Epoch 5 from 100
# 	Train Loss	 0.06654542
# 	Train Acc.	 0.99038464
# 	Val Loss	 0.04688976
# 	Val Acc.	 1.0
# 	Diff		 0.019655659794807434
# Epoch 6 from 100
# 	Train Loss	 0.049235463
# 	Train Acc.	 0.9855769
# 	Val Loss	 0.010762865
# 	Val Acc.	 1.0
# 	Diff		 0.038472600281238556
# Epoch 7 from 100
# 	Train Loss	 0.015095521
# 	Train Acc.	 1.0
# 	Val Loss	 0.0072530205
# 	Val Acc.	 1.0
# 	Diff		 0.007842499762773514
# Epoch 8 from 100
# 	Train Loss	 0.008788174
# 	Train Acc.	 1.0
# 	Val Loss	 0.004552491
# 	Val Acc.	 1.0
# 	Diff		 0.004235683009028435
# Epoch 9 from 100
# 	Train Loss	 0.0028032388
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010380712
# 	Val Acc.	 1.0
# 	Diff		 0.001765167573466897
# Epoch 10 from 100
# 	Train Loss	 0.0011764398
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006029756
# 	Val Acc.	 1.0
# 	Diff		 0.0005734642036259174
# Epoch 11 from 100
# 	Train Loss	 0.0005780126
# 	Train Acc.	 1.0
# 	Val Loss	 0.00039722692
# 	Val Acc.	 1.0
# 	Diff		 0.00018078568973578513
# Epoch 12 from 100
# 	Train Loss	 0.00042877326
# 	Train Acc.	 1.0
# 	Val Loss	 0.00034234137
# 	Val Acc.	 1.0
# 	Diff		 8.643188630230725e-05
# Epoch 13 from 100
# 	Train Loss	 0.00035388314
# 	Train Acc.	 1.0
# 	Val Loss	 0.0003019259
# 	Val Acc.	 1.0
# 	Diff		 5.195723497308791e-05
# Epoch 14 from 100
# 	Train Loss	 0.00030719026
# 	Train Acc.	 1.0
# 	Val Loss	 0.0002700725
# 	Val Acc.	 1.0
# 	Diff		 3.7117773899808526e-05
# Epoch 15 from 100
# 	Train Loss	 0.00027762313
# 	Train Acc.	 1.0
# 	Val Loss	 0.00024310508
# 	Val Acc.	 1.0
# 	Diff		 3.451804514043033e-05
# Epoch 16 from 100
# 	Train Loss	 0.00024720977
# 	Train Acc.	 1.0
# 	Val Loss	 0.00022190518
# 	Val Acc.	 1.0
# 	Diff		 2.530458732508123e-05
# Epoch 17 from 100
# 	Train Loss	 0.0002247635
# 	Train Acc.	 1.0
# 	Val Loss	 0.0002022654
# 	Val Acc.	 1.0
# 	Diff		 2.2498104954138398e-05
# Epoch 18 from 100
# 	Train Loss	 0.00020454258
# 	Train Acc.	 1.0
# 	Val Loss	 0.00018496215
# 	Val Acc.	 1.0
# 	Diff		 1.9580431398935616e-05
# Epoch 19 from 100
# 	Train Loss	 0.00018742037
# 	Train Acc.	 1.0
# 	Val Loss	 0.0001706138
# 	Val Acc.	 1.0
# 	Diff		 1.6806574421934783e-05
# Epoch 20 from 100
# 	Train Loss	 0.00017286035
# 	Train Acc.	 1.0
# 	Val Loss	 0.00015732451
# 	Val Acc.	 1.0
# 	Diff		 1.5535842976532876e-05
# Epoch 21 from 100
# 	Train Loss	 0.00015957112
# 	Train Acc.	 1.0
# 	Val Loss	 0.00014749718
# 	Val Acc.	 1.0
# 	Diff		 1.2073942343704402e-05
# Epoch 22 from 100
# 	Train Loss	 0.00014841
# 	Train Acc.	 1.0
# 	Val Loss	 0.00013788448
# 	Val Acc.	 1.0
# 	Diff		 1.05255312519148e-05
# Epoch 23 from 100
# 	Train Loss	 0.00013822483
# 	Train Acc.	 1.0
# 	Val Loss	 0.00012783227
# 	Val Acc.	 1.0
# 	Diff		 1.0392555850557983e-05
# Epoch 24 from 100
# 	Train Loss	 0.00012856297
# 	Train Acc.	 1.0
# 	Val Loss	 0.00012006979
# 	Val Acc.	 1.0
# 	Diff		 8.493181667290628e-06
# Epoch 25 from 100
# 	Train Loss	 0.00012103887
# 	Train Acc.	 1.0
# 	Val Loss	 0.00011326588
# 	Val Acc.	 1.0
# 	Diff		 7.772992830723524e-06
# Epoch 26 from 100
# 	Train Loss	 0.00011397185
# 	Train Acc.	 1.0
# 	Val Loss	 0.00010680684
# 	Val Acc.	 1.0
# 	Diff		 7.165013812482357e-06
# Epoch 27 from 100
# 	Train Loss	 0.000107651744
# 	Train Acc.	 1.0
# 	Val Loss	 0.00010048749
# 	Val Acc.	 1.0
# 	Diff		 7.164257112890482e-06
# Epoch 28 from 100
# 	Train Loss	 0.00010118497
# 	Train Acc.	 1.0
# 	Val Loss	 9.494416e-05
# 	Val Acc.	 1.0
# 	Diff		 6.24080712441355e-06
# Epoch 29 from 100
# 	Train Loss	 9.549804e-05
# 	Train Acc.	 1.0
# 	Val Loss	 9.043205e-05
# 	Val Acc.	 1.0
# 	Diff		 5.065994628239423e-06
# Epoch 30 from 100
# 	Train Loss	 9.076921e-05
# 	Train Acc.	 1.0
# 	Val Loss	 8.602074e-05
# 	Val Acc.	 1.0
# 	Diff		 4.748471837956458e-06
# Epoch 31 from 100
# 	Train Loss	 8.5994456e-05
# 	Train Acc.	 1.0
# 	Val Loss	 8.221069e-05
# 	Val Acc.	 1.0
# 	Diff		 3.7837671698071063e-06
# Epoch 32 from 100
# 	Train Loss	 8.191554e-05
# 	Train Acc.	 1.0
# 	Val Loss	 7.8585e-05
# 	Val Acc.	 1.0
# 	Diff		 3.3305404940620065e-06
# Epoch 33 from 100
# 	Train Loss	 7.767929e-05
# 	Train Acc.	 1.0
# 	Val Loss	 7.505441e-05
# 	Val Acc.	 1.0
# 	Diff		 2.6248744688928127e-06
# Epoch 34 from 100
# 	Train Loss	 7.449881e-05
# 	Train Acc.	 1.0
# 	Val Loss	 7.101751e-05
# 	Val Acc.	 1.0
# 	Diff		 3.481298335827887e-06
# Epoch 35 from 100
# 	Train Loss	 7.083991e-05
# 	Train Acc.	 1.0
# 	Val Loss	 6.8237125e-05
# 	Val Acc.	 1.0
# 	Diff		 2.602784661576152e-06
# Epoch 36 from 100
# 	Train Loss	 6.763824e-05
# 	Train Acc.	 1.0
# 	Val Loss	 6.525017e-05
# 	Val Acc.	 1.0
# 	Diff		 2.388071152381599e-06
# Epoch 37 from 100
# 	Train Loss	 6.478935e-05
# 	Train Acc.	 1.0
# 	Val Loss	 6.27249e-05
# 	Val Acc.	 1.0
# 	Diff		 2.0644438336603343e-06
# Epoch 38 from 100
# 	Train Loss	 6.210032e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.980317e-05
# 	Val Acc.	 1.0
# 	Diff		 2.297150786034763e-06
# Epoch 39 from 100
# 	Train Loss	 5.919756e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.752933e-05
# 	Val Acc.	 1.0
# 	Diff		 1.6682279238011688e-06
# Epoch 40 from 100
# 	Train Loss	 5.689186e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.5186632e-05
# 	Val Acc.	 1.0
# 	Diff		 1.7052261682692915e-06
# Epoch 41 from 100
# 	Train Loss	 5.4603886e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.3044947e-05
# 	Val Acc.	 1.0
# 	Diff		 1.5589394024573267e-06
# Epoch 42 from 100
# 	Train Loss	 5.255995e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.140787e-05
# 	Val Acc.	 1.0
# 	Diff		 1.1520787666086107e-06
# Epoch 43 from 100
# 	Train Loss	 5.04323e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.921785e-05
# 	Val Acc.	 1.0
# 	Diff		 1.214448275277391e-06
# Epoch 44 from 100
# 	Train Loss	 4.841418e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.7422567e-05
# 	Val Acc.	 1.0
# 	Diff		 9.916111594066024e-07
# Epoch 45 from 100
# 	Train Loss	 4.668365e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.5577035e-05
# 	Val Acc.	 1.0
# 	Diff		 1.1066149454563856e-06
# Epoch 46 from 100
# 	Train Loss	 4.4985212e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.414112e-05
# 	Val Acc.	 1.0
# 	Diff		 8.440911187790334e-07
# Epoch 47 from 100
# 	Train Loss	 4.332458e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.2435273e-05
# 	Val Acc.	 1.0
# 	Diff		 8.893075573723763e-07
# Epoch 48 from 100
# 	Train Loss	 4.1696632e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.1034764e-05
# 	Val Acc.	 1.0
# 	Diff		 6.618683983106166e-07
# Epoch 49 from 100
# 	Train Loss	 4.0451418e-05
# 	Train Acc.	 1.0
# 	Val Loss	 3.9477865e-05
# 	Val Acc.	 1.0
# 	Diff		 9.735522326081991e-07
# [EARLY STOP] Reached early stop at epoch 48.

# %% [markdown]
# ## Teilaufgabe d): Augmentierung

# %%
"""
Possible ways to augment the data would be to flip and rotate the images as well as add color filters like grayscale. Other possible techniques could be kernel filters (to change sharpness) or cropping the image
"""
from PIL import Image
from natsort import natsorted

def make_grayscale(input_file: str, output_file: str):
    image = Image.open(input_file)
    grayscale_image = image.convert('L')
    grayscale_image_3_chn = grayscale_image.convert('RGB')  # Must keep 3 channels
    grayscale_image_3_chn.save(output_file)

def flip_image(input_file: str, output_file: str):
    image = Image.open(input_file)
    flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
    flipped_image.save(output_file)


# Create new images
for folder in ('Flur', 'Labor', 'Professorenbuero', 'Teekueche'):
    # Delete existing images
    folder_path = f'Bilder/{folder}'
    files = natsorted([f for f in os.listdir(folder_path) if RE_FILE.match(f)])
    for i, file in enumerate(files):
        make_grayscale(f'{folder_path}/{file}', f'{folder_path}/{folder}_gray_{i + 1}.jpg')
        flip_image(f'{folder_path}/{file}', f'{folder_path}/{folder}_flipped_{i + 1}.jpg')

# %%
# Modify training / test / validation data
training_path_list, y_train, test_path_list, y_test, validation_path_list, y_val = create_full_data_split(base_only=False)

"""
Da die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.
Es scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint
"""
# Out:
# '\nDa die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.\nEs scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint\n'

# %% [markdown]
# ## Teilaufgabe e): Early Stopping

# %%
EARLY_STOP = True
"""
The overfitting stops and the training is faster
"""
# Out:
# '\nThe overfitting stops and the training is faster\n'

# %% [markdown]
# ## Teilaufgabe c): Training und Test mit CNN

# %% [markdown]
# Datenset-Klasse um mit Pytorch Bilder zu laden.
#
# Input sind:
# - Liste mit Pfaden zu Bildern
# - Liste mit dazugehörigen Labels (numerisch darstellen!)
# - Transformation der Bilder

# %%
class ROBDataset(Dataset):
    def __init__(self, img_path_list, img_labels, transform=None):
        # Pfade zu den Bildern als list
        self.img_path_list = img_path_list

        # Dazugehörige Labels zu den Bildern als list
        self.img_labels = img_labels

        # Transformations der Bilder
        self.transform = transform

    def __len__(self):
        return len(self.img_path_list)

    def __getitem__(self, idx):
        # Bild laden
        img_path = self.img_path_list[idx]
        image = read_image(img_path)

        # Label laden
        label = self.img_labels[idx]

        # Transformieren
        if self.transform:
            image = self.transform(image)

        return image.float(), int(label)

# %% [markdown]
# Trainingsiteration über alle Bilder.
#
# Inputs sind:
# - Pytorch dataloader Object über das iteriert wird
# - bool do_backprob Parameter um Backpropagation durchzuführen oder nicht

# %%
from torchmetrics import Accuracy
def accuracy_score(output, labels):
    output = torch.from_numpy(output)
    labels = torch.from_numpy(labels)
    acc = Accuracy(task="multiclass", num_classes=4)
    r = acc(output, labels)
    return r

# Iterating over the entire data set once
def run_iteration(dataloader, do_backprob=True):
    global net, optimizer, criterion
    loss_iter = []
    acc_iter = []
    for batch_x, batch_y in dataloader:
        # To device
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        y_predict = net(batch_x)
        loss = criterion(y_predict, batch_y)
        if do_backprob:
            loss.backward()
            optimizer.step()

        # statistics
        loss_iter.append(loss.detach().cpu().numpy())

        _, predicted = torch.max(torch.softmax(y_predict, dim=1),1)

        acc_iter.append(accuracy_score(batch_y.detach().cpu().numpy(),
                                       predicted.detach().cpu().numpy()))

    return np.mean(loss_iter), np.mean(acc_iter)

# %% [markdown]
# Komplette Durchführung eines Trainings
# Die Variablen y_train, y_val und y_test müssen noch gesetzt werden. Diese Listen beinhalten die entsprechenden Labels als numerische Darstellung.

# %%
# Get the device. This adds support for DirectML as I have an AMD GPU, which is a giant pain for machine learning (*cries over awful ROCm installation instructions*)
try:
    import torch_directml
    device = torch_directml.device()
    print('Found DirectML')
except ModuleNotFoundError:
    print('No DirectML found. Using CUDA / CPU instead')
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Found DirectML

# %%
# Training settings - bei Bedarf anpassbar
max_epoch = 100
batch_size = 16
lr = 0.001
early_stop_cnt = 0
early_stop_min_delta = 0.000001
early_stop_tolerance = 5

# Transformations for dataloader
t_train = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_val = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_test = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])

# Where to do calculations
print("Running on ", device)
print(f'Train / test images: {len(training_path_list)}/{len(test_path_list)}')

# Training Data, NOTE: y_train labels need to be set
dataset_train = ROBDataset(training_path_list, y_train, transform=t_train)
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# Validation Data, NOTE: y_val labels need to be set
dataset_val = ROBDataset(validation_path_list, y_val, transform=t_train)
dataloader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# Test Data, NOTE: y_test labels need. to be set
dataset_test = ROBDataset(test_path_list, y_test,transform=t_test)
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

# Network, optimizer and loss initialisation
net = Net()
net.to(device)
optimizer = optim.Adam(net.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# Los geht's mit Training
print("\nStarted Training")
# Training loss and accuracy per epoch
train_loss_epoch = []
train_acc_epoch = []
# Validation loss and accuracy per epoch
val_loss_epoch = []
val_acc_epoch = []

for epoch in range(0,max_epoch):  # loop over the dataset multiple times
    print(f"Epoch {epoch+1} from {max_epoch}")

    ### TRAINING ###
    net.train()
    train_loss_iter, train_acc_iter = run_iteration(dataloader_train)

    # Logging loss and accuarcy of training iteration
    train_loss_epoch.append(train_loss_iter)
    train_acc_epoch.append(train_acc_iter)
    print("\tTrain Loss\t",train_loss_iter)
    print("\tTrain Acc.\t",train_acc_iter)

    ### VALIDATION ###
    with torch.no_grad():  # No gradient calculation
        net.eval()
        val_loss_iter, val_acc_iter = run_iteration(dataloader_val,do_backprob=False)

        # Logging loss and accuarcy of validation iteration
        val_loss_epoch.append(val_loss_iter)
        val_acc_epoch.append(val_acc_iter)
        print("\tVal Loss\t",val_loss_iter)
        print("\tVal Acc.\t",val_acc_iter)

    if EARLY_STOP:
        loss_diff = abs(val_loss_iter - train_loss_iter)
        print(f'\tDiff\t\t {loss_diff}')
        if loss_diff < early_stop_min_delta:
            early_stop_cnt += 1
            if early_stop_cnt >= early_stop_tolerance:
                print(f"[EARLY STOP] Reached early stop at epoch {epoch}.")
                break

# Plotting results
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(10,3))
ax[0].plot(train_loss_epoch,label="Train")
ax[0].plot(val_loss_epoch,label="Val",linestyle="-.")
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epochs')
ax[0].legend()

ax[1].plot(train_acc_epoch,label="Train")
ax[1].plot(val_acc_epoch,label="Val",linestyle="-.")
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].legend()
plt.savefig("loss_augmentation.png",format="png",bbox_inches="tight")
plt.show()
# Out:
# 	Train Loss	 2.0786825e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008444871
# 	Val Acc.	 1.0
# 	Diff		 0.008424083702266216
# Epoch 54 from 100
# 	Train Loss	 2.0056157e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008244304
# 	Val Acc.	 1.0
# 	Diff		 0.008224247954785824
# Epoch 55 from 100
# 	Train Loss	 1.9361587e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008084561
# 	Val Acc.	 1.0
# 	Diff		 0.008065199479460716
# Epoch 56 from 100
# 	Train Loss	 1.8646959e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008140897
# 	Val Acc.	 1.0
# 	Diff		 0.008122250437736511
# Epoch 57 from 100
# 	Train Loss	 1.8057257e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008309218
# 	Val Acc.	 1.0
# 	Diff		 0.008291160687804222
# Epoch 58 from 100
# 	Train Loss	 1.7389044e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008133422
# 	Val Acc.	 1.0
# 	Diff		 0.008116032928228378
# Epoch 59 from 100
# 	Train Loss	 1.6818256e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.008021615
# 	Val Acc.	 1.0
# 	Diff		 0.008004797622561455
# Epoch 60 from 100
# 	Train Loss	 1.6278986e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007871865
# 	Val Acc.	 1.0
# 	Diff		 0.00785558670759201
# Epoch 61 from 100
# 	Train Loss	 1.5770085e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007848989
# 	Val Acc.	 1.0
# 	Diff		 0.00783321913331747
# Epoch 62 from 100
# 	Train Loss	 1.526004e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0076970034
# 	Val Acc.	 1.0
# 	Diff		 0.007681743241846561
# Epoch 63 from 100
# 	Train Loss	 1.4779221e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0076545603
# 	Val Acc.	 1.0
# 	Diff		 0.007639781106263399
# Epoch 64 from 100
# 	Train Loss	 1.4305277e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0077753603
# 	Val Acc.	 1.0
# 	Diff		 0.007761055137962103
# Epoch 65 from 100
# 	Train Loss	 1.391672e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007650719
# 	Val Acc.	 1.0
# 	Diff		 0.0076368022710084915
# Epoch 66 from 100
# 	Train Loss	 1.34576785e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0077058156
# 	Val Acc.	 1.0
# 	Diff		 0.007692357990890741
# Epoch 67 from 100
# 	Train Loss	 1.3062244e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007700938
# 	Val Acc.	 1.0
# 	Diff		 0.007687875535339117
# Epoch 68 from 100
# 	Train Loss	 1.267827e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0075782123
# 	Val Acc.	 1.0
# 	Diff		 0.007565534207969904
# Epoch 69 from 100
# 	Train Loss	 1.2312066e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0075630355
# 	Val Acc.	 1.0
# 	Diff		 0.007550723385065794
# Epoch 70 from 100
# 	Train Loss	 1.1986545e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007526283
# 	Val Acc.	 1.0
# 	Diff		 0.007514296565204859
# Epoch 71 from 100
# 	Train Loss	 1.1655298e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007670291
# 	Val Acc.	 1.0
# 	Diff		 0.007658635266125202
# Epoch 72 from 100
# 	Train Loss	 1.1309721e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0075113536
# 	Val Acc.	 1.0
# 	Diff		 0.007500044070184231
# Epoch 73 from 100
# 	Train Loss	 1.1005408e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0073150974
# 	Val Acc.	 1.0
# 	Diff		 0.007304091937839985
# Epoch 74 from 100
# 	Train Loss	 1.0693072e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0073813885
# 	Val Acc.	 1.0
# 	Diff		 0.007370695471763611
# Epoch 75 from 100
# 	Train Loss	 1.0415692e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.007258948
# 	Val Acc.	 1.0
# 	Diff		 0.007248532027006149
# Epoch 76 from 100
# 	Train Loss	 1.0136019e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0072336025
# 	Val Acc.	 1.0
# 	Diff		 0.007223466411232948
# Epoch 77 from 100
# 	Train Loss	 9.856348e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.007171108
# 	Val Acc.	 1.0
# 	Diff		 0.007161251734942198
# Epoch 78 from 100
# 	Train Loss	 9.6156455e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.007184129
# 	Val Acc.	 1.0
# 	Diff		 0.007174513768404722
# Epoch 79 from 100
# 	Train Loss	 9.361764e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0072180983
# 	Val Acc.	 1.0
# 	Diff		 0.00720873661339283
# Epoch 80 from 100
# 	Train Loss	 9.136534e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0071221925
# 	Val Acc.	 1.0
# 	Diff		 0.007113055791705847
# Epoch 81 from 100
# 	Train Loss	 8.879785e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0070306384
# 	Val Acc.	 1.0
# 	Diff		 0.007021758705377579
# Epoch 82 from 100
# 	Train Loss	 8.664872e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006973128
# 	Val Acc.	 1.0
# 	Diff		 0.00696446280926466
# Epoch 83 from 100
# 	Train Loss	 8.456263e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0068658963
# 	Val Acc.	 1.0
# 	Diff		 0.006857439875602722
# Epoch 84 from 100
# 	Train Loss	 8.259117e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006894911
# 	Val Acc.	 1.0
# 	Diff		 0.006886652205139399
# Epoch 85 from 100
# 	Train Loss	 8.049933e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0069525917
# 	Val Acc.	 1.0
# 	Diff		 0.006944541819393635
# Epoch 86 from 100
# 	Train Loss	 7.8711255e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0068634492
# 	Val Acc.	 1.0
# 	Diff		 0.006855578161776066
# Epoch 87 from 100
# 	Train Loss	 7.671111e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0068770023
# 	Val Acc.	 1.0
# 	Diff		 0.006869331002235413
# Epoch 88 from 100
# 	Train Loss	 7.4986083e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006822572
# 	Val Acc.	 1.0
# 	Diff		 0.006815073546022177
# Epoch 89 from 100
# 	Train Loss	 7.3266765e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006678042
# 	Val Acc.	 1.0
# 	Diff		 0.006670715287327766
# Epoch 90 from 100
# 	Train Loss	 7.149014e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006744526
# 	Val Acc.	 1.0
# 	Diff		 0.006737377028912306
# Epoch 91 from 100
# 	Train Loss	 6.9971406e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006666781
# 	Val Acc.	 1.0
# 	Diff		 0.006659783888608217
# Epoch 92 from 100
# 	Train Loss	 6.837244e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0066899476
# 	Val Acc.	 1.0
# 	Diff		 0.006683110259473324
# Epoch 93 from 100
# 	Train Loss	 6.6905295e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0065531866
# 	Val Acc.	 1.0
# 	Diff		 0.006546495947986841
# Epoch 94 from 100
# 	Train Loss	 6.5409495e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006565152
# 	Val Acc.	 1.0
# 	Diff		 0.006558611057698727
# Epoch 95 from 100
# 	Train Loss	 6.4194505e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.006459401
# 	Val Acc.	 1.0
# 	Diff		 0.006452981382608414
# Epoch 96 from 100
# 	Train Loss	 6.2624194e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0064653726
# 	Val Acc.	 1.0
# 	Diff		 0.006459110416471958
# Epoch 97 from 100
# 	Train Loss	 6.124873e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0064654574
# 	Val Acc.	 1.0
# 	Diff		 0.006459332536906004
# Epoch 98 from 100
# 	Train Loss	 5.993058e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0064763906
# 	Val Acc.	 1.0
# 	Diff		 0.0064703975804150105
# Epoch 99 from 100
# 	Train Loss	 5.8767173e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0063983616
# 	Val Acc.	 1.0
# 	Diff		 0.006392484996467829
# Epoch 100 from 100
# 	Train Loss	 5.7557922e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0063998373
# 	Val Acc.	 1.0
# 	Diff		 0.006394081749022007
# Running on  privateuseone:0
# Train / test images: 208/80
#
# Started Training
# Epoch 1 from 100
# 	Train Loss	 1.2728022
# 	Train Acc.	 0.37980768
# 	Val Loss	 0.9162694
# 	Val Acc.	 0.53125
# 	Diff		 0.3565328121185303
# Epoch 2 from 100
# 	Train Loss	 0.786911
# 	Train Acc.	 0.64903843
# 	Val Loss	 0.5326222
# 	Val Acc.	 0.796875
# 	Diff		 0.25428879261016846
# Epoch 3 from 100
# 	Train Loss	 0.42841834
# 	Train Acc.	 0.8269231
# 	Val Loss	 0.31028926
# 	Val Acc.	 0.90625
# 	Diff		 0.11812907457351685
# Epoch 4 from 100
# 	Train Loss	 0.18510501
# 	Train Acc.	 0.9423077
# 	Val Loss	 0.10747982
# 	Val Acc.	 1.0
# 	Diff		 0.07762519270181656
# Epoch 5 from 100
# 	Train Loss	 0.101359956
# 	Train Acc.	 0.96634614
# 	Val Loss	 0.10858789
# 	Val Acc.	 0.984375
# 	Diff		 0.007227934896945953
# Epoch 6 from 100
# 	Train Loss	 0.041573472
# 	Train Acc.	 0.9951923
# 	Val Loss	 0.021329261
# 	Val Acc.	 1.0
# 	Diff		 0.020244210958480835
# Epoch 7 from 100
# 	Train Loss	 0.01236373
# 	Train Acc.	 1.0
# 	Val Loss	 0.014879495
# 	Val Acc.	 1.0
# 	Diff		 0.002515764907002449
# Epoch 8 from 100
# 	Train Loss	 0.0020306977
# 	Train Acc.	 1.0
# 	Val Loss	 0.0040508644
# 	Val Acc.	 1.0
# 	Diff		 0.0020201667211949825
# Epoch 9 from 100
# 	Train Loss	 0.0009828485
# 	Train Acc.	 1.0
# 	Val Loss	 0.0026747258
# 	Val Acc.	 1.0
# 	Diff		 0.0016918773762881756
# Epoch 10 from 100
# 	Train Loss	 0.0005348012
# 	Train Acc.	 1.0
# 	Val Loss	 0.0035941326
# 	Val Acc.	 1.0
# 	Diff		 0.003059331327676773
# Epoch 11 from 100
# 	Train Loss	 0.0003553567
# 	Train Acc.	 1.0
# 	Val Loss	 0.0033452557
# 	Val Acc.	 1.0
# 	Diff		 0.0029898991342633963
# Epoch 12 from 100
# 	Train Loss	 0.00027055538
# 	Train Acc.	 1.0
# 	Val Loss	 0.0028022993
# 	Val Acc.	 1.0
# 	Diff		 0.002531744074076414
# Epoch 13 from 100
# 	Train Loss	 0.00022152076
# 	Train Acc.	 1.0
# 	Val Loss	 0.002465552
# 	Val Acc.	 1.0
# 	Diff		 0.0022440312895923853
# Epoch 14 from 100
# 	Train Loss	 0.0001915612
# 	Train Acc.	 1.0
# 	Val Loss	 0.0023161008
# 	Val Acc.	 1.0
# 	Diff		 0.002124539576470852
# Epoch 15 from 100
# 	Train Loss	 0.00016704111
# 	Train Acc.	 1.0
# 	Val Loss	 0.0022659018
# 	Val Acc.	 1.0
# 	Diff		 0.0020988606847822666
# Epoch 16 from 100
# 	Train Loss	 0.00014671117
# 	Train Acc.	 1.0
# 	Val Loss	 0.0023603167
# 	Val Acc.	 1.0
# 	Diff		 0.002213605446740985
# Epoch 17 from 100
# 	Train Loss	 0.00013036413
# 	Train Acc.	 1.0
# 	Val Loss	 0.00219622
# 	Val Acc.	 1.0
# 	Diff		 0.0020658557768911123
# Epoch 18 from 100
# 	Train Loss	 0.00011560196
# 	Train Acc.	 1.0
# 	Val Loss	 0.002200215
# 	Val Acc.	 1.0
# 	Diff		 0.0020846128463745117
# Epoch 19 from 100
# 	Train Loss	 0.00010311239
# 	Train Acc.	 1.0
# 	Val Loss	 0.0021323045
# 	Val Acc.	 1.0
# 	Diff		 0.002029192168265581
# Epoch 20 from 100
# 	Train Loss	 9.25341e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0019921022
# 	Val Acc.	 1.0
# 	Diff		 0.0018995681311935186
# Epoch 21 from 100
# 	Train Loss	 8.355141e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0019332467
# 	Val Acc.	 1.0
# 	Diff		 0.0018496953416615725
# Epoch 22 from 100
# 	Train Loss	 7.566708e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0019589833
# 	Val Acc.	 1.0
# 	Diff		 0.001883316203020513
# Epoch 23 from 100
# 	Train Loss	 6.89692e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0020477816
# 	Val Acc.	 1.0
# 	Diff		 0.0019788125064224005
# Epoch 24 from 100
# 	Train Loss	 6.1877494e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0017565659
# 	Val Acc.	 1.0
# 	Diff		 0.0016946883406490088
# Epoch 25 from 100
# 	Train Loss	 5.5997305e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0015969301
# 	Val Acc.	 1.0
# 	Diff		 0.0015409328043460846
# Epoch 26 from 100
# 	Train Loss	 5.1234583e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0016704148
# 	Val Acc.	 1.0
# 	Diff		 0.0016191801987588406
# Epoch 27 from 100
# 	Train Loss	 4.667332e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0017221222
# 	Val Acc.	 1.0
# 	Diff		 0.0016754488460719585
# Epoch 28 from 100
# 	Train Loss	 4.234582e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0017149162
# 	Val Acc.	 1.0
# 	Diff		 0.0016725703608244658
# Epoch 29 from 100
# 	Train Loss	 3.916093e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0016215007
# 	Val Acc.	 1.0
# 	Diff		 0.0015823397552594543
# Epoch 30 from 100
# 	Train Loss	 3.6340458e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0015568273
# 	Val Acc.	 1.0
# 	Diff		 0.0015204868977889419
# Epoch 31 from 100
# 	Train Loss	 3.3921686e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0015675415
# 	Val Acc.	 1.0
# 	Diff		 0.0015336198266595602
# Epoch 32 from 100
# 	Train Loss	 3.194986e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0015035764
# 	Val Acc.	 1.0
# 	Diff		 0.0014716265723109245
# Epoch 33 from 100
# 	Train Loss	 3.0345904e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0014489869
# 	Val Acc.	 1.0
# 	Diff		 0.0014186410699039698
# Epoch 34 from 100
# 	Train Loss	 2.8684097e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0014808639
# 	Val Acc.	 1.0
# 	Diff		 0.0014521797420457006
# Epoch 35 from 100
# 	Train Loss	 2.7283038e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0011941323
# 	Val Acc.	 1.0
# 	Diff		 0.0011668491642922163
# Epoch 36 from 100
# 	Train Loss	 2.6053878e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.001268497
# 	Val Acc.	 1.0
# 	Diff		 0.001242443104274571
# Epoch 37 from 100
# 	Train Loss	 2.4702043e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0014334937
# 	Val Acc.	 1.0
# 	Diff		 0.0014087916351854801
# Epoch 38 from 100
# 	Train Loss	 2.3556533e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0012420543
# 	Val Acc.	 1.0
# 	Diff		 0.0012184977531433105
# Epoch 39 from 100
# 	Train Loss	 2.247349e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0012035301
# 	Val Acc.	 1.0
# 	Diff		 0.0011810566065832973
# Epoch 40 from 100
# 	Train Loss	 2.15457e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0012380786
# 	Val Acc.	 1.0
# 	Diff		 0.0012165328953415155
# Epoch 41 from 100
# 	Train Loss	 2.0565216e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0011568128
# 	Val Acc.	 1.0
# 	Diff		 0.0011362475343048573
# Epoch 42 from 100
# 	Train Loss	 1.9585872e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0012537799
# 	Val Acc.	 1.0
# 	Diff		 0.0012341940309852362
# Epoch 43 from 100
# 	Train Loss	 1.899562e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0011179467
# 	Val Acc.	 1.0
# 	Diff		 0.0010989510919898748
# Epoch 44 from 100
# 	Train Loss	 1.8066126e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010920085
# 	Val Acc.	 1.0
# 	Diff		 0.0010739424033090472
# Epoch 45 from 100
# 	Train Loss	 1.7296497e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0011747575
# 	Val Acc.	 1.0
# 	Diff		 0.001157460967078805
# Epoch 46 from 100
# 	Train Loss	 1.6651222e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010858541
# 	Val Acc.	 1.0
# 	Diff		 0.001069202902726829
# Epoch 47 from 100
# 	Train Loss	 1.6035181e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010768543
# 	Val Acc.	 1.0
# 	Diff		 0.0010608191369101405
# Epoch 48 from 100
# 	Train Loss	 1.5358386e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.001070342
# 	Val Acc.	 1.0
# 	Diff		 0.0010549835860729218
# Epoch 49 from 100
# 	Train Loss	 1.486325e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010754233
# 	Val Acc.	 1.0
# 	Diff		 0.0010605601128190756
# Epoch 50 from 100
# 	Train Loss	 1.4336028e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010598552
# 	Val Acc.	 1.0
# 	Diff		 0.0010455191368237138
# Epoch 51 from 100
# 	Train Loss	 1.3808227e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010412417
# 	Val Acc.	 1.0
# 	Diff		 0.0010274334345012903
# Epoch 52 from 100
# 	Train Loss	 1.3326841e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0010250297
# 	Val Acc.	 1.0
# 	Diff		 0.0010117028141394258
# Epoch 53 from 100
# 	Train Loss	 1.3891801e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0005759345
# 	Val Acc.	 1.0
# 	Diff		 0.0005620426964014769
# Epoch 54 from 100
# 	Train Loss	 1.3286208e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.00036211906
# 	Val Acc.	 1.0
# 	Diff		 0.0003488328366074711
# Epoch 55 from 100
# 	Train Loss	 1.2329741e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.00062631944
# 	Val Acc.	 1.0
# 	Diff		 0.0006139897159300745
# Epoch 56 from 100
# 	Train Loss	 1.0905626e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007706989
# 	Val Acc.	 1.0
# 	Diff		 0.0007597932708449662
# Epoch 57 from 100
# 	Train Loss	 1.023912e-05
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007306825
# 	Val Acc.	 1.0
# 	Diff		 0.0007204433786682785
# Epoch 58 from 100
# 	Train Loss	 9.88953e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007698939
# 	Val Acc.	 1.0
# 	Diff		 0.0007600043318234384
# Epoch 59 from 100
# 	Train Loss	 9.518739e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0008059245
# 	Val Acc.	 1.0
# 	Diff		 0.0007964057149365544
# Epoch 60 from 100
# 	Train Loss	 9.218436e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00083010487
# 	Val Acc.	 1.0
# 	Diff		 0.000820886401925236
# Epoch 61 from 100
# 	Train Loss	 8.935901e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00074380776
# 	Val Acc.	 1.0
# 	Diff		 0.0007348718354478478
# Epoch 62 from 100
# 	Train Loss	 8.6728505e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007298865
# 	Val Acc.	 1.0
# 	Diff		 0.0007212136988528073
# Epoch 63 from 100
# 	Train Loss	 8.414956e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007881911
# 	Val Acc.	 1.0
# 	Diff		 0.0007797761354595423
# Epoch 64 from 100
# 	Train Loss	 8.163939e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00079592725
# 	Val Acc.	 1.0
# 	Diff		 0.0007877633324824274
# Epoch 65 from 100
# 	Train Loss	 7.91808e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007550951
# 	Val Acc.	 1.0
# 	Diff		 0.0007471769931726158
# Epoch 66 from 100
# 	Train Loss	 7.689415e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007817966
# 	Val Acc.	 1.0
# 	Diff		 0.0007741071749478579
# Epoch 67 from 100
# 	Train Loss	 7.4882564e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007314771
# 	Val Acc.	 1.0
# 	Diff		 0.0007239888655021787
# Epoch 68 from 100
# 	Train Loss	 7.293402e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00075382413
# 	Val Acc.	 1.0
# 	Diff		 0.0007465307135134935
# Epoch 69 from 100
# 	Train Loss	 7.096829e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.000644975
# 	Val Acc.	 1.0
# 	Diff		 0.0006378781399689615
# Epoch 70 from 100
# 	Train Loss	 6.9059865e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00065773336
# 	Val Acc.	 1.0
# 	Diff		 0.0006508273654617369
# Epoch 71 from 100
# 	Train Loss	 6.7374954e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0007122889
# 	Val Acc.	 1.0
# 	Diff		 0.0007055514142848551
# Epoch 72 from 100
# 	Train Loss	 6.5621257e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006837489
# 	Val Acc.	 1.0
# 	Diff		 0.0006771868211217225
# Epoch 73 from 100
# 	Train Loss	 6.3919147e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006795602
# 	Val Acc.	 1.0
# 	Diff		 0.0006731682806275785
# Epoch 74 from 100
# 	Train Loss	 6.2515037e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006496553
# 	Val Acc.	 1.0
# 	Diff		 0.0006434037932194769
# Epoch 75 from 100
# 	Train Loss	 6.080147e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006258097
# 	Val Acc.	 1.0
# 	Diff		 0.0006197295733727515
# Epoch 76 from 100
# 	Train Loss	 5.9299928e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00064898474
# 	Val Acc.	 1.0
# 	Diff		 0.0006430547218769789
# Epoch 77 from 100
# 	Train Loss	 5.7878633e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00061929465
# 	Val Acc.	 1.0
# 	Diff		 0.0006135067669674754
# Epoch 78 from 100
# 	Train Loss	 5.6606345e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006189499
# 	Val Acc.	 1.0
# 	Diff		 0.0006132892449386418
# Epoch 79 from 100
# 	Train Loss	 5.5219443e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006041385
# 	Val Acc.	 1.0
# 	Diff		 0.0005986165488138795
# Epoch 80 from 100
# 	Train Loss	 5.402164e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0005622125
# 	Val Acc.	 1.0
# 	Diff		 0.0005568103515543044
# Epoch 81 from 100
# 	Train Loss	 5.278948e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.00057524646
# 	Val Acc.	 1.0
# 	Diff		 0.0005699674948118627
# Epoch 82 from 100
# 	Train Loss	 5.1545826e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0006031291
# 	Val Acc.	 1.0
# 	Diff		 0.0005979745183140039
# Epoch 83 from 100
# 	Train Loss	 5.0428275e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0005387712
# 	Val Acc.	 1.0
# 	Diff		 0.0005337283946573734
# Epoch 84 from 100
# 	Train Loss	 4.941961e-06
# 	Train Acc.	 1.0
# 	Val Loss	 0.0005403336
# 	Val Acc.	 1.0
# 	Diff		 0.0005353916785679758
# Epoch 85 from 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 56
#      54 ### TRAINING ###
#      55 net.train()
# ---> 56 train_loss_iter, train_acc_iter = run_iteration(dataloader_train)
#      58 # Logging loss and accuarcy of training iteration
#      59 train_loss_epoch.append(train_loss_iter)
#
# Cell In[74], line 30, in run_iteration(dataloader, do_backprob)
#      27     optimizer.step()
#      29 # statistics
# ---> 30 loss_iter.append(loss.detach().cpu().numpy())
#      32 _, predicted = torch.max(torch.softmax(y_predict, dim=1),1)
#      34 acc_iter.append(accuracy_score(batch_y.detach().cpu().numpy(),
#      35                                predicted.detach().cpu().numpy()))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Teilaufgabe d): Augmentierung

# %%
"""
Possible ways to augment the data would be to flip and rotate the images as well as add color filters like grayscale. Other possible techniques could be kernel filters (to change sharpness) or cropping the image
"""
from PIL import Image
from natsort import natsorted

def make_grayscale(input_file: str, output_file: str):
    image = Image.open(input_file)
    grayscale_image = image.convert('L')
    grayscale_image_3_chn = grayscale_image.convert('RGB')  # Must keep 3 channels
    grayscale_image_3_chn.save(output_file)

def flip_image(input_file: str, output_file: str):
    image = Image.open(input_file)
    flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
    flipped_image.save(output_file)


# Create new images
for folder in ('Flur', 'Labor', 'Professorenbuero', 'Teekueche'):
    # Delete existing images
    folder_path = f'Bilder/{folder}'
    files = natsorted([f for f in os.listdir(folder_path) if RE_FILE.match(f)])
    for i, file in enumerate(files):
        make_grayscale(f'{folder_path}/{file}', f'{folder_path}/{folder}_gray_{i + 1}.jpg')
        flip_image(f'{folder_path}/{file}', f'{folder_path}/{folder}_flipped_{i + 1}.jpg')

# %%
# Modify training / test / validation data
training_path_list, y_train, test_path_list, y_test, validation_path_list, y_val = create_full_data_split(base_only=False)

"""
Da die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.
Es scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint
"""
# Out:
# '\nDa die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.\nEs scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint\n'

# %% [markdown]
# ## Teilaufgabe e): Early Stopping

# %%
EARLY_STOP = True
"""
The overfitting stops and the training is faster
"""
# Out:
# '\nThe overfitting stops and the training is faster\n'

# %% [markdown]
# ## Teilaufgabe c): Training und Test mit CNN

# %% [markdown]
# Datenset-Klasse um mit Pytorch Bilder zu laden.
#
# Input sind:
# - Liste mit Pfaden zu Bildern
# - Liste mit dazugehörigen Labels (numerisch darstellen!)
# - Transformation der Bilder

# %%
class ROBDataset(Dataset):
    def __init__(self, img_path_list, img_labels, transform=None):
        # Pfade zu den Bildern als list
        self.img_path_list = img_path_list
        
        # Dazugehörige Labels zu den Bildern als list
        self.img_labels = img_labels
        
        # Transformations der Bilder
        self.transform = transform

    def __len__(self):
        return len(self.img_path_list)

    def __getitem__(self, idx):
        # Bild laden
        img_path = self.img_path_list[idx]
        image = read_image(img_path)
        
        # Label laden
        label = self.img_labels[idx]
        
        # Transformieren
        if self.transform:
            image = self.transform(image)
            
        return image.float(), int(label)

# %% [markdown]
# Trainingsiteration über alle Bilder.
#
# Inputs sind:
# - Pytorch dataloader Object über das iteriert wird
# - bool do_backprob Parameter um Backpropagation durchzuführen oder nicht

# %%
from torchmetrics import Accuracy
def accuracy_score(output, labels):
    output = torch.from_numpy(output)
    labels = torch.from_numpy(labels)
    acc = Accuracy(task="multiclass", num_classes=4)
    r = acc(output, labels)
    return r

# Iterating over the entire data set once
def run_iteration(dataloader, do_backprob=True):
    global net, optimizer, criterion
    loss_iter = []
    acc_iter = []
    for batch_x, batch_y in dataloader:
        # To device
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        y_predict = net(batch_x)
        loss = criterion(y_predict, batch_y)
        if do_backprob:
            loss.backward()
            optimizer.step()

        # statistics
        loss_iter.append(loss.detach().cpu().numpy())
        
        _, predicted = torch.max(torch.softmax(y_predict, dim=1),1)
        
        acc_iter.append(accuracy_score(batch_y.detach().cpu().numpy(), 
                                       predicted.detach().cpu().numpy()))
    
    return np.mean(loss_iter), np.mean(acc_iter)

# %% [markdown]
# Komplette Durchführung eines Trainings
# Die Variablen y_train, y_val und y_test müssen noch gesetzt werden. Diese Listen beinhalten die entsprechenden Labels als numerische Darstellung.

# %%
# Get the device. This adds support for DirectML as I have an AMD GPU, which is a giant pain for machine learning (*cries over awful ROCm installation instructions*)
try:
    import torch_directml
    device = torch_directml.device()
    print('Found DirectML')
except ModuleNotFoundError:
    print('No DirectML found. Using CUDA / CPU instead')
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Found DirectML

# %%
# Training settings - bei Bedarf anpassbar
max_epoch = 100
batch_size = 16
lr = 0.001
early_stop_cnt = 0
early_stop_min_delta = 0.000001
early_stop_tolerance = 5

# Transformations for dataloader
t_train = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_val = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])
t_test = T.Compose([T.ToPILImage(),
                   T.ToTensor(),
                   T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))])

# Where to do calculations
print("Running on ", device)
print(f'Train / test images: {len(training_path_list)}/{len(test_path_list)}')

# Training Data, NOTE: y_train labels need to be set
dataset_train = ROBDataset(training_path_list, y_train, transform=t_train)
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

# Validation Data, NOTE: y_val labels need to be set
dataset_val = ROBDataset(validation_path_list, y_val, transform=t_train)
dataloader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False)

# Test Data, NOTE: y_test labels need. to be set
dataset_test = ROBDataset(test_path_list, y_test,transform=t_test)
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False)

# Network, optimizer and loss initialisation
net = Net()
net.to(device)
optimizer = optim.Adam(net.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

# Los geht's mit Training
print("\nStarted Training")
# Training loss and accuracy per epoch
train_loss_epoch = []
train_acc_epoch = []
# Validation loss and accuracy per epoch
val_loss_epoch = []
val_acc_epoch = []

for epoch in range(0,max_epoch):  # loop over the dataset multiple times
    print(f"Epoch {epoch+1} from {max_epoch}")
    
    ### TRAINING ###
    net.train()
    train_loss_iter, train_acc_iter = run_iteration(dataloader_train)

    # Logging loss and accuarcy of training iteration
    train_loss_epoch.append(train_loss_iter)
    train_acc_epoch.append(train_acc_iter)
    print("\tTrain Loss\t",train_loss_iter)
    print("\tTrain Acc.\t",train_acc_iter)
    
    ### VALIDATION ###
    with torch.no_grad():  # No gradient calculation
        net.eval()
        val_loss_iter, val_acc_iter = run_iteration(dataloader_val,do_backprob=False)

        # Logging loss and accuarcy of validation iteration
        val_loss_epoch.append(val_loss_iter)
        val_acc_epoch.append(val_acc_iter)
        print("\tVal Loss\t",val_loss_iter)
        print("\tVal Acc.\t",val_acc_iter)

    if EARLY_STOP:
        loss_diff = abs(val_loss_iter - train_loss_iter)
        print(f'\tDiff\t\t {loss_diff}')
        if loss_diff < early_stop_min_delta:
            early_stop_cnt += 1
            if early_stop_cnt >= early_stop_tolerance:
                print(f"[EARLY STOP] Reached early stop at epoch {epoch}.")
                break

# Plotting results
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(10,3))
ax[0].plot(train_loss_epoch,label="Train")
ax[0].plot(val_loss_epoch,label="Val",linestyle="-.")
ax[0].set_ylabel('Loss')
ax[0].set_xlabel('Epochs')
ax[0].legend()

ax[1].plot(train_acc_epoch,label="Train")
ax[1].plot(val_acc_epoch,label="Val",linestyle="-.")
ax[1].set_ylabel('Accuracy')
ax[1].set_xlabel('Epochs')
ax[1].legend()
plt.savefig("loss_augmentation.png",format="png",bbox_inches="tight")
plt.show()
# Out:
# Running on  privateuseone:0
# Train / test images: 208/80
#
# Started Training
# Epoch 1 from 100
# 	Train Loss	 1.3032777
# 	Train Acc.	 0.37019232
# 	Val Loss	 0.9173988
# 	Val Acc.	 0.796875
# 	Diff		 0.38587892055511475
# Epoch 2 from 100
# 	Train Loss	 0.78828275
# 	Train Acc.	 0.72596157
# 	Val Loss	 0.5567719
# 	Val Acc.	 0.765625
# 	Diff		 0.23151087760925293
# Epoch 3 from 100
# 	Train Loss	 0.43641
# 	Train Acc.	 0.83653843
# 	Val Loss	 0.23377186
# 	Val Acc.	 0.953125
# 	Diff		 0.2026381492614746
# Epoch 4 from 100
# 	Train Loss	 0.1857303
# 	Train Acc.	 0.9519231
# 	Val Loss	 0.08495173
# 	Val Acc.	 0.984375
# 	Diff		 0.10077856481075287
# Epoch 5 from 100
# 	Train Loss	 0.053366046
# 	Train Acc.	 0.9855769
# 	Val Loss	 0.009492269
# 	Val Acc.	 1.0
# 	Diff		 0.043873779475688934
# Epoch 6 from 100
# 	Train Loss	 0.007627798
# 	Train Acc.	 1.0
# 	Val Loss	 0.0022159156
# 	Val Acc.	 1.0
# 	Diff		 0.0054118819534778595
# Epoch 7 from 100
# 	Train Loss	 0.0026057004
# 	Train Acc.	 1.0
# 	Val Loss	 0.00108092
# 	Val Acc.	 1.0
# 	Diff		 0.001524780411273241
# Epoch 8 from 100
# 	Train Loss	 0.0010273933
# 	Train Acc.	 1.0
# 	Val Loss	 0.0005476504
# 	Val Acc.	 1.0
# 	Diff		 0.0004797428846359253
# Epoch 9 from 100
# 	Train Loss	 0.0006135354
# 	Train Acc.	 1.0
# 	Val Loss	 0.0003473946
# 	Val Acc.	 1.0
# 	Diff		 0.00026614079251885414
# Epoch 10 from 100
# 	Train Loss	 0.0004198831
# 	Train Acc.	 1.0
# 	Val Loss	 0.00026971276
# 	Val Acc.	 1.0
# 	Diff		 0.0001501703227404505
# Epoch 11 from 100
# 	Train Loss	 0.0003348261
# 	Train Acc.	 1.0
# 	Val Loss	 0.00021546773
# 	Val Acc.	 1.0
# 	Diff		 0.00011935835937038064
# Epoch 12 from 100
# 	Train Loss	 0.00027502488
# 	Train Acc.	 1.0
# 	Val Loss	 0.00017927818
# 	Val Acc.	 1.0
# 	Diff		 9.574669820722193e-05
# Epoch 13 from 100
# 	Train Loss	 0.00022595449
# 	Train Acc.	 1.0
# 	Val Loss	 0.00015457661
# 	Val Acc.	 1.0
# 	Diff		 7.137787179090083e-05
# Epoch 14 from 100
# 	Train Loss	 0.00019309677
# 	Train Acc.	 1.0
# 	Val Loss	 0.0001350541
# 	Val Acc.	 1.0
# 	Diff		 5.8042671298608184e-05
# Epoch 15 from 100
# 	Train Loss	 0.0001678273
# 	Train Acc.	 1.0
# 	Val Loss	 0.000120239216
# 	Val Acc.	 1.0
# 	Diff		 4.758808063343167e-05
# Epoch 16 from 100
# 	Train Loss	 0.000145687
# 	Train Acc.	 1.0
# 	Val Loss	 0.00010347483
# 	Val Acc.	 1.0
# 	Diff		 4.221216659061611e-05
# Epoch 17 from 100
# 	Train Loss	 0.00012737063
# 	Train Acc.	 1.0
# 	Val Loss	 9.319056e-05
# 	Val Acc.	 1.0
# 	Diff		 3.41800696332939e-05
# Epoch 18 from 100
# 	Train Loss	 0.00011257453
# 	Train Acc.	 1.0
# 	Val Loss	 8.392556e-05
# 	Val Acc.	 1.0
# 	Diff		 2.8648973966483027e-05
# Epoch 19 from 100
# 	Train Loss	 0.00010061211
# 	Train Acc.	 1.0
# 	Val Loss	 7.536672e-05
# 	Val Acc.	 1.0
# 	Diff		 2.5245390133932233e-05
# Epoch 20 from 100
# 	Train Loss	 9.108381e-05
# 	Train Acc.	 1.0
# 	Val Loss	 6.907677e-05
# 	Val Acc.	 1.0
# 	Diff		 2.2007043298799545e-05
# Epoch 21 from 100
# 	Train Loss	 8.246017e-05
# 	Train Acc.	 1.0
# 	Val Loss	 6.272019e-05
# 	Val Acc.	 1.0
# 	Diff		 1.973997859749943e-05
# Epoch 22 from 100
# 	Train Loss	 7.56827e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.6989047e-05
# 	Val Acc.	 1.0
# 	Diff		 1.869365223683417e-05
# Epoch 23 from 100
# 	Train Loss	 6.9379625e-05
# 	Train Acc.	 1.0
# 	Val Loss	 5.250887e-05
# 	Val Acc.	 1.0
# 	Diff		 1.6870755644049495e-05
# Epoch 24 from 100
# 	Train Loss	 6.384249e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.9179565e-05
# 	Val Acc.	 1.0
# 	Diff		 1.4662924513686448e-05
# Epoch 25 from 100
# 	Train Loss	 5.9145306e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.588159e-05
# 	Val Acc.	 1.0
# 	Diff		 1.3263717846712098e-05
# Epoch 26 from 100
# 	Train Loss	 5.4448476e-05
# 	Train Acc.	 1.0
# 	Val Loss	 4.204898e-05
# 	Val Acc.	 1.0
# 	Diff		 1.2399494153214619e-05
# Epoch 27 from 100
# 	Train Loss	 5.1268926e-05
# 	Train Acc.	 1.0
# 	Val Loss	 3.9298433e-05
# 	Val Acc.	 1.0
# 	Diff		 1.1970492778345942e-05
# Epoch 28 from 100
# 	Train Loss	 4.7375466e-05
# 	Train Acc.	 1.0
# 	Val Loss	 3.7371432e-05
# 	Val Acc.	 1.0
# 	Diff		 1.0004034265875816e-05
# Epoch 29 from 100
# 	Train Loss	 4.4367785e-05
# 	Train Acc.	 1.0
# 	Val Loss	 3.4903976e-05
# 	Val Acc.	 1.0
# 	Diff		 9.463808964937925e-06
# Epoch 30 from 100
# 	Train Loss	 4.1541043e-05
# 	Train Acc.	 1.0
# 	Val Loss	 3.2158932e-05
# 	Val Acc.	 1.0
# 	Diff		 9.382110874867067e-06
# Epoch 31 from 100
# 	Train Loss	 3.9366398e-05
# 	Train Acc.	 1.0
# 	Val Loss	 3.0592633e-05
# 	Val Acc.	 1.0
# 	Diff		 8.773764420766383e-06
# Epoch 32 from 100
# 	Train Loss	 3.6914458e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.9153221e-05
# 	Val Acc.	 1.0
# 	Diff		 7.761236702208407e-06
# Epoch 33 from 100
# 	Train Loss	 3.4893954e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.7484566e-05
# 	Val Acc.	 1.0
# 	Diff		 7.409387762891129e-06
# Epoch 34 from 100
# 	Train Loss	 3.2872864e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.6117632e-05
# 	Val Acc.	 1.0
# 	Diff		 6.7552318796515465e-06
# Epoch 35 from 100
# 	Train Loss	 3.130845e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.458864e-05
# 	Val Acc.	 1.0
# 	Diff		 6.7198088800068945e-06
# Epoch 36 from 100
# 	Train Loss	 2.9773837e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.3633258e-05
# 	Val Acc.	 1.0
# 	Diff		 6.14057898928877e-06
# Epoch 37 from 100
# 	Train Loss	 2.8350401e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.2333314e-05
# 	Val Acc.	 1.0
# 	Diff		 6.0170877986820415e-06
# Epoch 38 from 100
# 	Train Loss	 2.7007169e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.1327642e-05
# 	Val Acc.	 1.0
# 	Diff		 5.679527021129616e-06
# Epoch 39 from 100
# 	Train Loss	 2.5774536e-05
# 	Train Acc.	 1.0
# 	Val Loss	 2.045231e-05
# 	Val Acc.	 1.0
# 	Diff		 5.32222657056991e-06
# Epoch 40 from 100
# 	Train Loss	 2.464274e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.9528543e-05
# 	Val Acc.	 1.0
# 	Diff		 5.114197847433388e-06
# Epoch 41 from 100
# 	Train Loss	 2.3572833e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.8668117e-05
# 	Val Acc.	 1.0
# 	Diff		 4.904715751763433e-06
# Epoch 42 from 100
# 	Train Loss	 2.2531021e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.8051636e-05
# 	Val Acc.	 1.0
# 	Diff		 4.479385097511113e-06
# Epoch 43 from 100
# 	Train Loss	 2.1524731e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.737744e-05
# 	Val Acc.	 1.0
# 	Diff		 4.147290383116342e-06
# Epoch 44 from 100
# 	Train Loss	 2.0634765e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.6559836e-05
# 	Val Acc.	 1.0
# 	Diff		 4.074929165653884e-06
# Epoch 45 from 100
# 	Train Loss	 1.9865704e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.5891223e-05
# 	Val Acc.	 1.0
# 	Diff		 3.974480932811275e-06
# Epoch 46 from 100
# 	Train Loss	 1.9049654e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.5261716e-05
# 	Val Acc.	 1.0
# 	Diff		 3.787938112509437e-06
# Epoch 47 from 100
# 	Train Loss	 1.8333898e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.475327e-05
# 	Val Acc.	 1.0
# 	Diff		 3.5806278901873156e-06
# Epoch 48 from 100
# 	Train Loss	 1.7602655e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.4241077e-05
# 	Val Acc.	 1.0
# 	Diff		 3.3615779102547094e-06
# Epoch 49 from 100
# 	Train Loss	 1.692242e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.3723315e-05
# 	Val Acc.	 1.0
# 	Diff		 3.1991057767299935e-06
# Epoch 50 from 100
# 	Train Loss	 1.6329284e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.3213e-05
# 	Val Acc.	 1.0
# 	Diff		 3.1162844607024454e-06
# Epoch 51 from 100
# 	Train Loss	 1.573558e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.2820014e-05
# 	Val Acc.	 1.0
# 	Diff		 2.915567165473476e-06
# Epoch 52 from 100
# 	Train Loss	 1.5219229e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.2367434e-05
# 	Val Acc.	 1.0
# 	Diff		 2.851795215974562e-06
# Epoch 53 from 100
# 	Train Loss	 1.4655325e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.1978171e-05
# 	Val Acc.	 1.0
# 	Diff		 2.677154043340124e-06
# Epoch 54 from 100
# 	Train Loss	 1.41951405e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.1577737e-05
# 	Val Acc.	 1.0
# 	Diff		 2.61740387941245e-06
# Epoch 55 from 100
# 	Train Loss	 1.3666758e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.1266696e-05
# 	Val Acc.	 1.0
# 	Diff		 2.4000619305297732e-06
# Epoch 56 from 100
# 	Train Loss	 1.3216316e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.0832739e-05
# 	Val Acc.	 1.0
# 	Diff		 2.383577339060139e-06
# Epoch 57 from 100
# 	Train Loss	 1.2797965e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.0555224e-05
# 	Val Acc.	 1.0
# 	Diff		 2.2427402655011974e-06
# Epoch 58 from 100
# 	Train Loss	 1.2419727e-05
# 	Train Acc.	 1.0
# 	Val Loss	 1.01771375e-05
# 	Val Acc.	 1.0
# 	Diff		 2.242589289380703e-06
# Epoch 59 from 100
# 	Train Loss	 1.2055816e-05
# 	Train Acc.	 1.0
# 	Val Loss	 9.823257e-06
# 	Val Acc.	 1.0
# 	Diff		 2.2325593818095513e-06
# Epoch 60 from 100
# 	Train Loss	 1.16088095e-05
# 	Train Acc.	 1.0
# 	Val Loss	 9.592304e-06
# 	Val Acc.	 1.0
# 	Diff		 2.016505277424585e-06
# Epoch 61 from 100
# 	Train Loss	 1.1271834e-05
# 	Train Acc.	 1.0
# 	Val Loss	 9.342724e-06
# 	Val Acc.	 1.0
# 	Diff		 1.929110112541821e-06
# Epoch 62 from 100
# 	Train Loss	 1.0948612e-05
# 	Train Acc.	 1.0
# 	Val Loss	 9.000021e-06
# 	Val Acc.	 1.0
# 	Diff		 1.948590579559095e-06
# Epoch 63 from 100
# 	Train Loss	 1.0662064e-05
# 	Train Acc.	 1.0
# 	Val Loss	 8.817493e-06
# 	Val Acc.	 1.0
# 	Diff		 1.8445707610226236e-06
# Epoch 64 from 100
# 	Train Loss	 1.0283253e-05
# 	Train Acc.	 1.0
# 	Val Loss	 8.530663e-06
# 	Val Acc.	 1.0
# 	Diff		 1.7525899238535203e-06
# Epoch 65 from 100
# 	Train Loss	 9.997851e-06
# 	Train Acc.	 1.0
# 	Val Loss	 8.266183e-06
# 	Val Acc.	 1.0
# 	Diff		 1.7316679077339359e-06
# Epoch 66 from 100
# 	Train Loss	 9.710158e-06
# 	Train Acc.	 1.0
# 	Val Loss	 8.05013e-06
# 	Val Acc.	 1.0
# 	Diff		 1.660027919569984e-06
# Epoch 67 from 100
# 	Train Loss	 9.447109e-06
# 	Train Acc.	 1.0
# 	Val Loss	 7.860147e-06
# 	Val Acc.	 1.0
# 	Diff		 1.5869618437136523e-06
# Epoch 68 from 100
# 	Train Loss	 9.18807e-06
# 	Train Acc.	 1.0
# 	Val Loss	 7.65527e-06
# 	Val Acc.	 1.0
# 	Diff		 1.5328005247283727e-06
# Epoch 69 from 100
# 	Train Loss	 8.9513815e-06
# 	Train Acc.	 1.0
# 	Val Loss	 7.4708764e-06
# 	Val Acc.	 1.0
# 	Diff		 1.4805050341237802e-06
# Epoch 70 from 100
# 	Train Loss	 8.678588e-06
# 	Train Acc.	 1.0
# 	Val Loss	 7.2492335e-06
# 	Val Acc.	 1.0
# 	Diff		 1.429354142601369e-06
# Epoch 71 from 100
# 	Train Loss	 8.461384e-06
# 	Train Acc.	 1.0
# 	Val Loss	 7.055529e-06
# 	Val Acc.	 1.0
# 	Diff		 1.405855073244311e-06
# Epoch 72 from 100
# 	Train Loss	 8.241314e-06
# 	Train Acc.	 1.0
# 	Val Loss	 6.8636855e-06
# 	Val Acc.	 1.0
# 	Diff		 1.377628905174788e-06
# Epoch 73 from 100
# 	Train Loss	 8.030989e-06
# 	Train Acc.	 1.0
# 	Val Loss	 6.7351684e-06
# 	Val Acc.	 1.0
# 	Diff		 1.295820766245015e-06
# Epoch 74 from 100
# 	Train Loss	 7.819514e-06
# 	Train Acc.	 1.0
# 	Val Loss	 6.5749887e-06
# 	Val Acc.	 1.0
# 	Diff		 1.2445257198123727e-06
# Epoch 75 from 100
# 	Train Loss	 7.6286724e-06
# 	Train Acc.	 1.0
# 	Val Loss	 6.4017704e-06
# 	Val Acc.	 1.0
# 	Diff		 1.2269019862287678e-06
# Epoch 76 from 100
# 	Train Loss	 7.40459e-06
# 	Train Acc.	 1.0
# 	Val Loss	 6.243452e-06
# 	Val Acc.	 1.0
# 	Diff		 1.1611382433329709e-06
# Epoch 77 from 100
# 	Train Loss	 7.2446956e-06
# 	Train Acc.	 1.0
# 	Val Loss	 6.1074848e-06
# 	Val Acc.	 1.0
# 	Diff		 1.1372108019713778e-06
# Epoch 78 from 100
# 	Train Loss	 7.0561455e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.98828e-06
# 	Val Acc.	 1.0
# 	Diff		 1.0678654689399991e-06
# Epoch 79 from 100
# 	Train Loss	 6.8968225e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.8094734e-06
# 	Val Acc.	 1.0
# 	Diff		 1.0873491191887297e-06
# Epoch 80 from 100
# 	Train Loss	 6.738646e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.6735066e-06
# 	Val Acc.	 1.0
# 	Diff		 1.0651392585714348e-06
# Epoch 81 from 100
# 	Train Loss	 6.557547e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.550577e-06
# 	Val Acc.	 1.0
# 	Diff		 1.0069697964354418e-06
# Epoch 82 from 100
# 	Train Loss	 6.411406e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.427647e-06
# 	Val Acc.	 1.0
# 	Diff		 9.837590368988458e-07
# Epoch 83 from 100
# 	Train Loss	 6.269276e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.3326544e-06
# 	Val Acc.	 1.0
# 	Diff		 9.366217454953585e-07
# Epoch 84 from 100
# 	Train Loss	 6.119696e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.2115874e-06
# 	Val Acc.	 1.0
# 	Diff		 9.081086318474263e-07
# Epoch 85 from 100
# 	Train Loss	 5.991894e-06
# 	Train Acc.	 1.0
# 	Val Loss	 5.0942454e-06
# 	Val Acc.	 1.0
# 	Diff		 8.976485332823358e-07
# Epoch 86 from 100
# 	Train Loss	 5.840594e-06
# 	Train Acc.	 1.0
# 	Val Loss	 4.9601394e-06
# 	Val Acc.	 1.0
# 	Diff		 8.804545359453186e-07
# [EARLY STOP] Reached early stop at epoch 85.

# %% [markdown]
# ## Teilaufgabe d): Augmentierung

# %%
"""
Possible ways to augment the data would be to flip and rotate the images as well as add color filters like grayscale. Other possible techniques could be kernel filters (to change sharpness) or cropping the image
"""
from PIL import Image
from natsort import natsorted

def make_grayscale(input_file: str, output_file: str):
    image = Image.open(input_file)
    grayscale_image = image.convert('L')
    grayscale_image_3_chn = grayscale_image.convert('RGB')  # Must keep 3 channels
    grayscale_image_3_chn.save(output_file)

def flip_image(input_file: str, output_file: str):
    image = Image.open(input_file)
    flipped_image = image.transpose(Image.FLIP_LEFT_RIGHT)
    flipped_image.save(output_file)


# Create new images
for folder in ('Flur', 'Labor', 'Professorenbuero', 'Teekueche'):
    # Delete existing images
    folder_path = f'Bilder/{folder}'
    files = natsorted([f for f in os.listdir(folder_path) if RE_FILE.match(f)])
    for i, file in enumerate(files):
        make_grayscale(f'{folder_path}/{file}', f'{folder_path}/{folder}_gray_{i + 1}.jpg')
        flip_image(f'{folder_path}/{file}', f'{folder_path}/{folder}_flipped_{i + 1}.jpg')

# %%
# Modify training / test / validation data
training_path_list, y_train, test_path_list, y_test, validation_path_list, y_val = create_full_data_split(base_only=False)

# Now run the training cell again

"""
Da die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.
Es scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint
"""
# Out:
# '\nDa die Performance schon von Anfang an bei 100% lag, verbessert sich durch die Augmentierung nichts.\nEs scheint sogar so, als würde sich das Model auf Dauer verschlechtern, da es zu overfiten scheint\n'

# %% [markdown]
# ## Teilaufgabe e): Early Stopping

# %%
EARLY_STOP = True

# Now run the training cell again

"""
The overfitting stops and the training is faster
"""
# Out:
# '\nThe overfitting stops and the training is faster\n'
